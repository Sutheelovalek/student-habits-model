# %%
import pandas as pd
df = pd.read_csv("student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum()
# Out:
# np.int64(91)

# %%
df = df.dropna()

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include="object").columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_cols = ["gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"]

# %%
for col in categorical_cols:
    print(f"Value counts for {col}: \n {df[col].value_counts()}")
# Out:
# Value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# Value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# Value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# Value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# Value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# Value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor="black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data=df, x =col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation = 45)
    plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.007150           -0.023854
# study_hours_per_day    0.007150             1.000000            0.007364
# social_media_hours    -0.023854             0.007364            1.000000
# netflix_hours          0.005841            -0.014493            0.011865
# attendance_percentage -0.030203             0.028967            0.049356
# sleep_hours            0.040498            -0.026241            0.026861
# exercise_frequency    -0.005718            -0.024708           -0.023975
# mental_health_rating  -0.052137            -0.015896           -0.000417
# exam_score            -0.012833             0.822950           -0.171672
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                         0.005841              -0.030203     0.040498
# study_hours_per_day        -0.014493               0.028967    -0.026241
# social_media_hours          0.011865               0.049356     0.026861
# netflix_hours               1.000000              -0.015008    -0.017006
# attendance_percentage      -0.015008               1.000000     0.001972
# sleep_hours                -0.017006               0.001972     1.000000
# exercise_frequency         -0.004155              -0.010563     0.030013
# mental_health_rating       -0.016612              -0.017096    -0.010653
# exam_score                 -0.166578               0.096005     0.122294
#
#                        exercise_frequency  mental_health_rating  exam_score
# age                             -0.005718             -0.052137   -0.012833
# study_hours_per_day             -0.024708             -0.015896    0.822950
# social_media_hours              -0.023975             -0.000417   -0.171672
# netflix_hours                   -0.004155             -0.016612   -0.166578
# attendance_percentage           -0.010563             -0.017096    0.096005
# sleep_hours                      0.030013             -0.010653    0.122294
# exercise_frequency               1.000000             -0.001500    0.161397
# mental_health_rating            -0.001500              1.000000    0.317945
# exam_score                       0.161397              0.317945    1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = ['age','study_hours_per_day','social_media_hours','netflix_hours','attendance_percentage', 'sleep_hours', 'exercise_frequency','mental_health_rating']

# %%
for feature in num_features:
    sns.scatterplot(data = df, x = feature, y = "exam_score")
    plt.title(f"{feature} vs Exam Score") 
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data = df, x = col, y = "exam_score")
    plt.title(f"Exam Score by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge 
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ["study_hours_per_day","attendance_percentage","mental_health_rating","sleep_hours","part_time_job"]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model.head(5)
# Out:
#    study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                  0.0                   85.0                     8
# 1                  6.9                   97.3                     8
# 2                  1.4                   94.8                     1
# 3                  1.0                   71.0                     1
# 4                  5.0                   90.9                     1
#
#    sleep_hours part_time_job  exam_score
# 0          8.0            No        56.2
# 1          4.6            No       100.0
# 2          8.0            No        34.3
# 3          9.2            No        26.8
# 4          4.9            No        66.4

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X = df_model[features]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": {
        "model": LinearRegression(),
        "params": {}
    },
    "DecisionTree" : {
        "model": DecisionTreeRegressor(),
        "params": {"max_depth": [3,5,10], "min_samples_split": [2,5]}
    },
    "RandomForest": {
        "model": RandomForestRegressor(),
        "params": {"n_estimators": [50,100], "max_depth": [5,10]}
    }
}

# %%
best_models = []

# %%
for name, config in models.items():
    print(f"Training {name}")

    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model":name,
        "best_params": grid.best_params_,
        "rmse" : rmse,
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(6.5521613407073795),
#   'r2': 0.8516400959348738},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 5},
#   'rmse': np.float64(7.882674778327815),
#   'r2': 0.7852690746177503},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 10, 'n_estimators': 100},
#   'rmse': np.float64(7.011834932720222),
#   'r2': 0.8300932059527388}]

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  6.552161
# 2      RandomForest    {'max_depth': 10, 'n_estimators': 100}  7.011835
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  7.882675
#
#          r2
# 0  0.851640
# 2  0.830093
# 1  0.785269

# %%
import joblib

best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   6.552161
# r2                      0.85164
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
# final_model.predict(X_test)
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 57.59364973,  66.22583241,  80.39472169,  86.35977735,
#         63.2526023 ,  51.31066723,  79.58150708,  75.58766803,
#         97.56842667,  71.42430502,  91.52584331,  71.62634586,
#         64.17680333,  97.04729563,  70.61133466, 101.01138266,
#         84.1404169 ,  84.17072978,  72.25779551,  53.00815757,
#         59.13466046,  81.1148883 ,  57.63384029,  67.24642978,
#         76.90551635,  67.77673736,  66.42722397,  83.39081928,
#         56.52867139,  65.04552732,  71.55786423,  58.02616961,
#         51.96864857,  63.00446683,  57.60239563,  54.97205488,
#         53.41330638,  86.1259658 ,  63.64001696,  91.82549796,
#         61.10861881,  63.08783432,  65.9872718 ,  54.8320808 ,
#        100.00884675,  59.38276315,  84.62669148,  86.30137744,
#         95.61742841,  54.84649087,  70.95686872,  34.07217639,
#         85.77985132,  79.75220639,  49.96712965,  98.07031515,
#         85.05249299,  59.16887727,  48.56143345,  78.89418139,
#         72.96464702,  69.95368226,  45.83696497,  77.28506823,
#         58.99100986,  86.17103408,  66.25211042,  69.31005922,
#         68.37208385,  52.76981731,  67.1142276 ,  70.20854282,
#         73.37721953,  92.69074923,  64.13092859,  73.19341212,
#         97.86319106,  64.22442454, 101.49785175,  66.56581535,
#         94.97908174,  67.71027466,  87.76819727,  60.08723101,
#         66.33382306,  63.09414629,  41.0826638 ,  76.55263164,
#         85.05701304,  48.21064224,  57.43241342,  45.2446473 ,
#         59.88818359,  60.92025364,  70.40477667,  49.90983882,
#         60.6209758 ,  73.59376451,  85.31749649,  78.99961143,
#         61.76235132,  43.50243593,  63.3153885 ,  66.31366546,
#         22.90568775,  54.1809859 ,  40.60113112,  85.23484959,
#         77.22980026,  78.79038574,  56.58691108,  81.43685695,
#        102.67076152,  62.62439   ,  58.48066121,  82.25691263,
#         72.4395309 ,  62.97716783,  77.0077602 , 105.01596237,
#         62.39081909,  71.56094773,  54.77778489,  64.81002362,
#         79.68363838,  70.63722799,  95.41329797,  50.09576014,
#         58.31327072,  43.87777281,  83.07636937,  70.56670815,
#        102.83147733,  58.59515015,  86.51178448,  51.25205314,
#         68.64068393,  68.67649345,  89.8219083 ,  64.33742269,
#         71.16917324,  71.9069882 ,  83.96961185,  55.14195272,
#         70.19382401,  74.29479694,  57.75569122,  33.01259124,
#         46.4743203 ,  66.00468079,  86.85962666,  80.46322951,
#         67.17994482,  66.7077738 ,  70.4414203 ,  79.30877704,
#         57.45595147,  87.69201972,  89.69195799,  89.38708519,
#         92.59169846,  74.30904731,  78.70663792,  90.35284716,
#         40.85472813,  74.8589124 ,  87.78875123,  66.85495635,
#         57.45957817,  66.55221819,  58.60039915,  69.37049503,
#         53.49737655,  84.71786767,  55.50712337,  58.11862611,
#         71.17382137,  93.96567609,  67.09112318,  65.24574029,
#         93.5987542 ,  78.25531747])
